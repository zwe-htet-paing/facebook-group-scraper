# %%
from facebook_scraping_selenium.extractor import Extractor

extractor = Extractor()

source_file = "data/raw/139534991092226.html"

df = extractor.extract_data(source_file=source_file)
df.head()
# Out:
#                                             post_url               user_id  \
# 0  https://www.facebook.com/groups/13953499109222...   ser/61550844142509/
# 1  https://www.facebook.com/groups/13953499109222...  ser/100090012653088/
# 2                                               None                  None
# 3  https://www.facebook.com/groups/13953499109222...  ser/100089105658129/
# 4                                                  #  ser/100090214749072/
#
#          username                                          post_text  \
# 0    Thet Eain RE                               Thet Eain Realestate
# 1       အလင်း သစ်  Shwe Kyal\n                                   ...
# 2            None
# 3    Thi Ha Naing                                       Thi Ha Naing
# 4  Emernal Wutyee                                     Emernal Wutyee
#
#                  time                                    shared_post_url  \
# 0 2024-02-19 23:00:00  https://www.facebook.com/permalink.php?story_f...
# 1 2024-02-19 20:00:00  https://www.facebook.com/groups/13819510059359...
# 2                 NaT
# 3 2024-02-19 23:00:00  https://www.facebook.com/thi.ha.naing258588/po...
# 4 2024-02-19 23:00:00                                                  #
#
#         shared_user_id       shared_username  \
# 0      100063921980380  Thet Eain Realestate
# 1  ser/61555985472654/             Shwe Kyal
# 2
# 3   thi.ha.naing258588          Thi Ha Naing
# 4      100090214749072        Emernal Wutyee
#
#                                          shared_text          shared_time  \
# 0  စမ်းချောင်းမြို့နယ် ပေကျယ်တိုက်ခန်းအရောင်း\n  ...  2024-02-19 23:00:00
# 1  သာကေတမင်းနန်ဒါလမ်းမနီး\n                      ...  2024-02-19 20:00:00
# 2
# 3  #စမ်းချောင်းမြို့နယ်_မြေညီတိုက်ခန်း_အရောင်း\n ...  2024-02-19 23:00:00
# 4  ကြည်မြင်တိုင်ဝှိုက်တောအနီးအငှားခန်းလေးပါ\n    ...  2024-02-19 23:00:00
#
#                                               images
# 0  [https://scontent.xx.fbcdn.net/v/t39.30808-6/4...
# 1  [https://scontent.xx.fbcdn.net/v/t39.30808-6/4...
# 2                                                 []
# 3  [https://scontent.xx.fbcdn.net/v/t39.30808-6/4...
# 4  [https://scontent.xx.fbcdn.net/v/t39.30808-6/4...

# %%
print("time", len(df[df.time.notna()]))
print("post_url",len(df[df.post_url.notna()]))
# Out:
# time 191
# post_url 191

# %%
from facebook_scraping_selenium.extractor import Extractor
from nayar_scraper import preprocess_df

# %%
from glob import glob
import os


date_string = "2024-02-20"
folder_path = f"data/raw/{date_string}"
output_path = f"data/scrape_data/{date_string}"
os.makedirs(output_path, exist_ok=True)

for raw_file in glob(os.path.join(folder_path, "*.html")):
    group_id = raw_file.split("/")[-1].split(".")[0]
    # print(raw_file)
    # print(group_id)
    temp_df = extractor.extract_data(source_file=raw_file)
    clean_df = preprocess_df(temp_df, date_list=[date_string], filter_date=False)
    extractor.write_csv(clean_df, f"{output_path}/group_{group_id}_{len(clean_df)}.csv")
# Out:
# data/raw/2024-02-20/201054442524126.html
# 201054442524126
# data/raw/2024-02-20/581035366216772.html
# 581035366216772
# data/raw/2024-02-20/1605099990009060.html
# 1605099990009060
# data/raw/2024-02-20/139534991092226.html
# 139534991092226

# %%
import pandas as pd

def get_data_for_one_date(folder_path: str):
    # Convert date string to datetime.date object
    # date_object = datetime.strptime(date_string, '%Y-%m-%d').date()
    # print("[INFO] DATE: ", date_string)
    
    # folder_path = os.path.join(data_path, date_string)
    file_list = glob(os.path.join(folder_path, '*.csv'))
    
    final_df = pd.DataFrame()
    
    for file in file_list:
        print(file)
        group_id = file.split('/')[-1].split('.')[-2].split('_')[-2]

        temp_df = pd.read_csv(file)
               
        # Add 'group_id' column
        temp_df['group_id'] = group_id
   
        # Concatenate to the final DataFrame
        final_df = pd.concat([final_df, temp_df], ignore_index=True)

    # Drop duplicates based on 'text' column
    final_df.drop_duplicates(subset=['text'], inplace=True)

    # Reset index
    final_df.reset_index(drop=True, inplace=True)

    return final_df

# %%
final_df = get_data_for_one_date(output_path)
final_df.head()
# Out:
# data/scrape_data/2024-02-20/group_201054442524126_104.csv
# data/scrape_data/2024-02-20/group_581035366216772_104.csv
# data/scrape_data/2024-02-20/group_1605099990009060_104.csv
# data/scrape_data/2024-02-20/group_139534991092226_104.csv
#                                             post_url               user_id  \
# 0  https://www.facebook.com/groups/20105444252412...   ser/61553123019778/
# 1  https://www.facebook.com/groups/20105444252412...  ser/100090918152387/
# 2  https://www.facebook.com/groups/20105444252412...  ser/100086218014205/
# 3  https://www.facebook.com/groups/20105444252412...  ser/100087530049760/
# 4  https://www.facebook.com/groups/20105444252412...  ser/100033865723266/
#
#          username                                          post_text  \
# 0  Thet Paing Soe  Thet Paing Soe\n                              ...
# 1         Nay Win                                                NaN
# 2     Ei Zin Phyo                                                NaN
# 3       Unty Than                                                NaN
# 4  Khin Sharr May  #ရောင်းမည်\n                                  ...
#
#                   time                                    shared_post_url  \
# 0  2024-02-19 01:00:00                                                NaN
# 1  2024-02-19 21:00:00  https://www.facebook.com/groups/88970427224022...
# 2  2024-02-19 11:00:00  https://www.facebook.com/permalink.php?story_f...
# 3  2024-02-19 10:00:00  https://www.facebook.com/groups/14869236346669...
# 4  2024-02-19 08:00:00                                                NaN
#
#          shared_user_id shared_username  \
# 0                   NaN             NaN
# 1  ser/100090644076869/       Htet Htet
# 2       100086218014205     Ei Zin Phyo
# 3  ser/100087530049760/       Unty Than
# 4                   NaN             NaN
#
#                                          shared_text          shared_time  \
# 0                                                NaN                  NaN
# 1  အလုံမြို့နယ် ဆင်မင်းစျေးအနီး\n                ...  2024-02-19 21:00:00
# 2  မင်္ဂလာပါ ရှင်\n                              ...  2024-02-19 11:00:00
# 3  #ကြည့်မြင်တိုင်မြို့နယ်တိုက်ခန်းအရောင်း\n     ...  2024-02-19 10:00:00
# 4                                                NaN                  NaN
#
#                                               images  \
# 0                                                 []
# 1  ['https://scontent.frgn2-2.fna.fbcdn.net/v/t39...
# 2  ['https://scontent.frgn2-1.fna.fbcdn.net/v/t39...
# 3  ['https://scontent.frgn2-1.fna.fbcdn.net/v/t39...
# 4  ['https://scontent.frgn2-1.fna.fbcdn.net/v/t39...
#
#                                                 text          post_id  \
# 0  Thet Paing Soe\n                              ...  394946276468274
# 1  အလုံမြို့နယ် ဆင်မင်းစျေးအနီး\n                ...  395465329749702
# 2  မင်္ဂလာပါ ရှင်\n                              ...  395226446440257
# 3  #ကြည့်မြင်တိုင်မြို့နယ်တိုက်ခန်းအရောင်း\n     ...  395208623108706
# 4  #ရောင်းမည်\n                                  ...  395144083115160
#
#           group_id
# 0  201054442524126
# 1  201054442524126
# 2  201054442524126
# 3  201054442524126
# 4  201054442524126

# %%
final_output = 'data/output'
os.makedirs(final_output, exist_ok=True)

output_file_path = os.path.join(final_output, f"{date_string}_output_{len(final_df)}.csv")
final_df.to_csv(output_file_path, index=False)
